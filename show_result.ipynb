# %%
import numpy as np
import matplotlib.pyplot as plt
from tools import denormdata
# %matplotlib inline

# set display defaults
plt.rcParams['figure.figsize'] = (50, 50)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

data = np.load("../record/outputs.npz")
data.files
# Out:
# ['test_out', 'test_in']

# %%
#for encoder
test_outputs = data['test_reconstruct_output']
test_outputs = denormdata(test_outputs)
print(test_outputs.shape)
test_ins = data['test_in']
test_ins = denormdata(test_ins)
print(test_ins.shape)

'''
plt.figure(1)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_in = test_ins[j*(-1)-1,0]
    plt.imshow(tmp_in.reshape(64,-1))
    plt.axis('off')
'''

plt.figure(2)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_out = test_outputs[j,0,:]
    plt.imshow(tmp_out.reshape(64,-1))
    plt.axis('off')
# Out:
# (10, 50, 4096)
# (10, 49, 4096)

# %%
#for future predictor
test_outputs = data['test_predict_output']
test_outputs = denormdata(test_outputs)
print(test_outputs.shape)
test_ins = data['test_in']
test_ins = denormdata(test_ins)
print(test_ins.shape)


plt.figure(1)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_in = test_ins[j, 0]
    plt.imshow(tmp_in.reshape(64,-1))
    plt.axis('off')

plt.figure(2)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_out = test_outputs[j,0,:]
    plt.imshow(tmp_out.reshape(64,-1))
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-f942b451a5b4> in <module>()
#       1 #for future predictor
# ----> 2 test_outputs = data['test_predict_output']
#       3 test_outputs = denormdata(test_outputs)
#       4 print(test_outputs.shape)
#       5 test_ins = data['test_in']
#
# ~/opt/miniconda3/envs/lab/lib/python3.6/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     235                 return self.zip.read(key)
#     236         else:
# --> 237             raise KeyError("%s is not a file in the archive" % key)
#     238
#     239     def __iter__(self):
#
# KeyError: 'test_predict_output is not a file in the archive'

# %%
#for future predictor
test_outputs = data['test_out']
test_outputs = denormdata(test_outputs)
print(test_outputs.shape)
test_ins = data['test_in']
test_ins = denormdata(test_ins)
print(test_ins.shape)


plt.figure(1)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_in = test_ins[j, 0]
    plt.imshow(tmp_in.reshape(64,-1))
    plt.axis('off')

plt.figure(2)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_out = test_outputs[j,0,:]
    plt.imshow(tmp_out.reshape(64,-1))
    plt.axis('off')
# Out:
# (10, 10, 4096)
# (10, 10, 4096)

# %%
test_outputs = data['test_out']
print(test_outputs.shape)
test_ins = data['test_in']
print(test_ins.shape)
batch_se = [((x-y)**2).mean(axis=1) for x, y in zip(test_ins[::-1],test_outputs)]
print(batch_se[0].shape)
print(len(batch_se))
mse = [x.mean() for x in batch_se]
print(len(mse))
print(mse)
tmp = [((x-y)**2).mean() for x, y in zip(test_ins[::-1,0],test_outputs[:,0])]
print(len(tmp))
#print(tmp)
frame_no = range(40)
plt.plot(frame_no, mse, linewidth=5.0)
plt.show()
# Out:
# (40, 5, 4096)
# (40, 5, 4096)
# (5,)
# 40
# 40
# [0.020173568, 0.02117091, 0.021236548, 0.020775175, 0.020857027, 0.021112841, 0.021994485, 0.022307444, 0.022046406, 0.022840317, 0.02284559, 0.021790527, 0.021594767, 0.020720482, 0.020672308, 0.021308359, 0.021055851, 0.019905102, 0.020953026, 0.021106582, 0.021030795, 0.021812836, 0.022486467, 0.02278734, 0.022708725, 0.023060136, 0.022247672, 0.022160519, 0.023168858, 0.02305611, 0.022556094, 0.022270883, 0.022127301, 0.022044133, 0.021897808, 0.021844128, 0.021752233, 0.021676147, 0.021655273, 0.022991979]
# 40

# %%
#for encoder
test_outputs = data['test_out']
#test_outputs = denormdata(test_outputs)
print(test_outputs.shape)
test_ins = data['test_in']
#test_ins = denormdata(test_ins)
print(test_ins.shape)

plt.figure(1)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_in = test_ins[j*(-1)-1,0]
    plt.imshow(tmp_in.reshape(64,-1))
    plt.axis('off')

plt.figure(2)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_out = test_outputs[j,0,:]
    plt.imshow(tmp_out.reshape(64,-1))
    plt.axis('off')

#imshow(solver.net.blobs['data'].data[:8, 0].transpose(1, 0, 2).reshape(28, 8*28), cmap='gray'); axis('off')
#print(test_ins[19:9:-1, 0].shape)

#plt.imshow(test_ins[19:9:-1, 0].reshape(64, 10*64), cmap='gray', aspect='auto')
#plt.imshow(test_ins[19:9:-1, 0].transpose(1,0).reshape(64, 10*64), cmap='gray', aspect='auto')
#plt.axis('off')
# Out:
# (20, 30, 4096)
# (20, 30, 4096)
