# %%
import numpy as np
import matplotlib.pyplot as plt
from tools import denormdata
# %matplotlib inline

# set display defaults
plt.rcParams['figure.figsize'] = (50, 50)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %%
#path for records
rec2500="../allrecords/record2500-450/outputs.npz"
conv30="../allrecords/conv30-300/outputs.npz"

# %%
#get the ddta of inputs and outputs
inputs = np.load(rec2500)['test_in']
outputs2500 = np.load(rec2500)['test_out']
outputs30 = np.load(conv30)['test_out']
outputslist = [outputs2500, outputs30]

# %%
#plot inputs
plt.figure(1)
for j in range(10):
    plt.subplot(1, 10, j+1)
    tmp_in = inputs[j*(-1)-1,1]
    plt.imshow(tmp_in.reshape(64,-1))
    plt.axis('off')

#plot outputs
for i, output in enumerate(outputslist):
    plt.figure(i+2)
    for j in range(10):
        plt.subplot(1, 10, j+1)
        tmp_out = output[j,1,:]
        plt.imshow(tmp_out.reshape(64,-1))
        plt.axis('off')
